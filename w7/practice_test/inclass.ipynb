# %%
for i in range(6,1,-1):
    print(i, end = f"{i}")
# Out:
# 6655443322

# %% [markdown]
# # ^^ check out me!

# %%
fruits = ["apple", "banana", "cherry"]

for fruit in fruits:
    print(fruit)
    
fruit = fruits
# Out:
# apple
# banana
# cherry
